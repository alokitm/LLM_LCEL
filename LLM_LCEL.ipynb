# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
groq_api_key = os.getenv("GROQ_API_KEY")

# %%
# !pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in d:\genai\lcel_groq\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-groq) (1.4.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\genai\lcel_groq\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\genai\lcel_groq\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.13.4)
# Requirement already satisfied: sniffio in c:\users\aloki\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.10)
# Requirement already satisfied: certifi in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\genai\lcel_groq\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\genai\lcel_groq\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\genai\lcel_groq\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain-groq) (2.5.0)

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model_name="llama-3.1-8b-instant",
    groq_api_key=groq_api_key
)

# %%
# !pip install langchain_core
# Out:
# Requirement already satisfied: langchain_core in c:\users\aloki\appdata\roaming\python\python313\site-packages (1.4.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\genai\lcel_groq\venv\lib\site-packages (from langchain_core) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (4.11.0)
# Requirement already satisfied: certifi in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\genai\lcel_groq\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\genai\lcel_groq\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\genai\lcel_groq\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.1)

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages=[
    SystemMessage(content="Translate the following from English to French"),
    HumanMessage(content="Hello How are you?")
]

result=model.invoke(messages)
result
# Out:
# AIMessage(content='Bonjour Comment allez-vous ?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 47, 'total_tokens': 54, 'completion_time': 0.013013959, 'completion_tokens_details': None, 'prompt_time': 0.002457261, 'prompt_tokens_details': None, 'queue_time': 0.054843259, 'total_time': 0.01547122}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e68bf-ab58-7bc1-a188-22c66d1b0e57-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 7, 'total_tokens': 54})
