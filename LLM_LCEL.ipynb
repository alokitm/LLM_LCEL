# %%
import os 
from dotenv import load_dotenv
load_dotenv()

groq_api_key=os.getenv("GROQ_API_KEY")

# %%
pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Using cached langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Using cached groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_groq) (1.4.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.11.0)
# Collecting distro<2,>=1.7.0 (from groq<1.0.0,>=0.30.0->langchain_groq)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\genai\lcel_groq\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.13.4)
# Requirement already satisfied: sniffio in c:\users\aloki\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.10)
# Requirement already satisfied: certifi in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\genai\lcel_groq\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\genai\lcel_groq\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\genai\lcel_groq\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.5.0)
# Using cached langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Using cached groq-0.37.1-py3-none-any.whl (137 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Installing collected packages: distro, groq, langchain_groq
#
#    ---------------------------------------- 0/3 [distro]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    ------------- -------------------------- 1/3 [groq]
#    -------------------------- ------------- 2/3 [langchain_groq]
#    ---------------------------------------- 3/3 [langchain_groq]
#
# Successfully installed distro-1.9.0 groq-0.37.1 langchain_groq-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="Gemma2-9b-It",groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(output_version=None, profile={}, client=<groq.resources.chat.completions.Completions object at 0x0000017172371090>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000017172371A90>, model_name='Gemma2-9b-It', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
pip install langchain_core

from langchain_core.messages import HumanMessage,SystemMessage
# Out:
# Requirement already satisfied: langchain_core in c:\users\aloki\appdata\roaming\python\python313\site-packages (1.4.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\genai\lcel_groq\venv\lib\site-packages (from langchain_core) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langchain_core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\genai\lcel_groq\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (4.11.0)
# Requirement already satisfied: certifi in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\genai\lcel_groq\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\genai\lcel_groq\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\genai\lcel_groq\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aloki\appdata\roaming\python\python313\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
